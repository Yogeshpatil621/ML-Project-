# %% [markdown]
# # Decision Tree (Classification) Practical

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
dataset = pd.read_csv("bill_authentication.csv")
dataset.head(3)
# Out:
#    Variance  Skewness  Curtosis  Entropy  Class
# 0    3.6216    8.6661   -2.8073 -0.44699      0
# 1    4.5459    8.1674   -2.4586 -1.46210      0
# 2    3.8660   -2.6383    1.9242  0.10645      0

# %%
dataset.isnull().sum()
# Out:
# Variance    0
# Skewness    0
# Curtosis    0
# Entropy     0
# Class       0
# dtype: int64

# %%
x=dataset.iloc[:,:-1]
y=dataset["Entropy"]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(x)
x = pd.DataFrame(sc.transform(x), columns=x.columns)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor

# %% [raw]
# # Initialize and fit the model
# dt = DecisionTreeRegressor()
# dt.fit(x_train, y_train)

# %%
dt.score(x_test,y_test)*100
# Out:
# -127.87287721145103

# %%
from sklearn.tree import plot_tree

# %%
# Plot the decision tree
plt.figure(figsize=(50, 50))
plt.savefig("tree.jpg")
plot_tree(dt)
plt.show()

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x="Variance", y="Skewness", data=dataset, hue="Entropy")
plt.show()

# %%
# Plot the decision regions
plt.figure(figsize=(15, 15))
plot_decision_regions(x.to_numpy(), y.to_numpy(), clf=dt)
plt.xlabel('feature1')
plt.ylabel('feature2')
plt.title('Decision Tree Decision Regions')
plt.show()
# Out:
# C:\Users\Smart\anaconda\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # pre pruning

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
dataset=pd.read_csv("bill_authentication.csv")
dataset.head(3)
# Out:
#    Variance  Skewness  Curtosis  Entropy  Class
# 0    3.6216    8.6661   -2.8073 -0.44699      0
# 1    4.5459    8.1674   -2.4586 -1.46210      0
# 2    3.8660   -2.6383    1.9242  0.10645      0

# %%
dataset.isnull().sum()
# Out:
# Variance    0
# Skewness    0
# Curtosis    0
# Entropy     0
# Class       0
# dtype: int64

# %%
x=dataset.iloc[:,:-1]
y=dataset["Entropy"]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(x)
x = pd.DataFrame(sc.transform(x), columns=x.columns)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
d1 = DecisionTreeClassifier(max_depth=5)
d1.fit(x_train, y_train_binned)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
d1.score(x_train,y_train_binned)*100
# Out:
# 100.0

# %%
# Plot the decision regions
plt.figure(figsize=(5, 5))
plot_tree(d1)
plt.show()

# %% [raw]
# plot_decision_regions(x.to_numpy(), y.to_numpy(), clf=dt)
# plt.show()
