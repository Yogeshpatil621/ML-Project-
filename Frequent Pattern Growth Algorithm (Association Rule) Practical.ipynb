# %% [markdown]
# # Frequent Pattern Growth Algorithm (Association Rule) Practical

# %%
import pandas  as pd

# %%
dataset=pd.read_csv("groceries - groceries.csv")
dataset.head(3)
# Out:
#    Item(s)          Item 1               Item 2     Item 3       Item 4  \
# 0        4    citrus fruit  semi-finished bread  margarine  ready soups
# 1        3  tropical fruit               yogurt     coffee          NaN
# 2        1      whole milk                  NaN        NaN          NaN
#
#   Item 5 Item 6 Item 7 Item 8 Item 9  ... Item 23 Item 24 Item 25 Item 26  \
# 0    NaN    NaN    NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN
# 1    NaN    NaN    NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN
# 2    NaN    NaN    NaN    NaN    NaN  ...     NaN     NaN     NaN     NaN
#
#   Item 27 Item 28 Item 29 Item 30 Item 31 Item 32
# 0     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN
#
# [3 rows x 33 columns]

# %%
dataset.shape
# Out:
# (9835, 33)

# %%
market= []
for i in range (0,dataset.shape[0]):
    cus=[]
    for j in dataset.columns:
        if type(dataset[j][i])==str:
            cus.append(dataset[j][i])
            market.append(cus)

# %%
market
# Out:
# [['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups'],
#  ['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups'],
#  ['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups'],
#  ['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups'],
#  ['tropical fruit', 'yogurt', 'coffee'],
#  ['tropical fruit', 'yogurt', 'coffee'],
#  ['tropical fruit', 'yogurt', 'coffee'],
#  ['whole milk'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product'],
#  ['other vegetables',
# ...

# %%
import time

ll = []
start_time = time.time()
for i in market:
    for j in market:
        l.append(j)
        if len(ll) % 1000 == 0:  # Log progress every 1000 iterations
            print(f"Processed {len(ll)} items in {time.time() - start_time:.2f} seconds")
# Out:
# Processed 0 items in 0.00 seconds
# Processed 0 items in 0.00 seconds
# Processed 0 items in 0.01 seconds
# Processed 0 items in 0.01 seconds
# Processed 0 items in 0.01 seconds
# Processed 0 items in 0.01 seconds
# Processed 0 items in 0.01 seconds
# Processed 0 items in 0.01 seconds
# Processed 0 items in 0.01 seconds
# Processed 0 items in 0.02 seconds
# Processed 0 items in 0.02 seconds
# Processed 0 items in 0.03 seconds
# Processed 0 items in 0.03 seconds
# Processed 0 items in 0.03 seconds
# Processed 0 items in 0.03 seconds
# Processed 0 items in 0.03 seconds
# Processed 0 items in 0.04 seconds
# Processed 0 items in 0.04 seconds
# Processed 0 items in 0.04 seconds
# Processed 0 items in 0.04 seconds
# Processed 0 items in 0.04 seconds
# Processed 0 items in 0.04 seconds
# Processed 0 items in 0.04 seconds
# Processed 0 items in 0.04 seconds
# Processed 0 items in 0.05 seconds
# Processed 0 items in 0.05 seconds
# Processed 0 items in 0.05 seconds
# ...

# %%
import collections

# Assuming `l` is the list you're working with

# Filter out unhashable items (if necessary)
#l_hashable = [item for item in l if isinstance(item, (int, str, tuple))]

# Now create the Counter with the hashable list
p = collections.Counter(ll)

# %%
d={"Item Name":p.keys(),"value":()}

# %%
from mlxtend.preprocessing.transactionencoder import TransactionEncoder

# %%
tr = TransactionEncoder()
tr.fit(market)
# Out:
# TransactionEncoder()

# %%
tr.transform(market)
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
df=pd.DataFrame(tr.transform(market),columns=tr.columns_)

# %%
df
# Out:
#        Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                      False     False             False             False
# 1                      False     False             False             False
# 2                      False     False             False             False
# 3                      False     False             False             False
# 4                      False     False             False             False
# ...                      ...       ...               ...               ...
# 43362                  False     False             False             False
# 43363                  False     False             False             False
# 43364                  False     False             False             False
# 43365                  False     False             False             False
# 43366                  False     False             False             False
#
# ...

# %%
from mlxtend.frequent_patterns import fpgrowth

# %%
fpgrowth(df,min_support=0.07,use_colnames=True,max_len=3)
# Out:
#      support                             itemsets
# 0   0.143796                       (citrus fruit)
# 1   0.104711                          (margarine)
# 2   0.237808                             (yogurt)
# 3   0.186109                     (tropical fruit)
# 4   0.089953                             (coffee)
# 5   0.391865                         (whole milk)
# 6   0.134019                          (pip fruit)
# 7   0.074250                       (cream cheese)
# 8   0.326700                   (other vegetables)
# 9   0.107593                             (butter)
# 10  0.250306                         (rolls/buns)
# 11  0.098808                       (bottled beer)
# 12  0.161528                      (bottled water)
# 13  0.085849                          (chocolate)
# 14  0.077847                        (white bread)
# 15  0.095672                               (curd)
# 16  0.091959                               (beef)
# 17  0.232804                               (soda)
# ...
